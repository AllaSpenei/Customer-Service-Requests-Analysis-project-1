# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('311_Service_Requests_from_2010_to_Present.csv')
# Out:
# <ipython-input-2-d77b9a8b305f>:1: DtypeWarning: Columns (48,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv('311_Service_Requests_from_2010_to_Present.csv')

# %%
dataset
# Out:
#         Unique Key            Created Date             Closed Date Agency  \
# 0         32310363  12/31/2015 11:59:45 PM           01-01-16 0:55   NYPD
# 1         32309934  12/31/2015 11:59:44 PM           01-01-16 1:26   NYPD
# 2         32309159  12/31/2015 11:59:29 PM           01-01-16 4:51   NYPD
# 3         32305098  12/31/2015 11:57:46 PM           01-01-16 7:43   NYPD
# 4         32306529  12/31/2015 11:56:58 PM           01-01-16 3:24   NYPD
# ...            ...                     ...                     ...    ...
# 300693    30281872  03/29/2015 12:33:41 AM                     NaN   NYPD
# 300694    30281230  03/29/2015 12:33:28 AM  03/29/2015 02:33:59 AM   NYPD
# 300695    30283424  03/29/2015 12:33:03 AM  03/29/2015 03:40:20 AM   NYPD
# 300696    30280004  03/29/2015 12:33:02 AM  03/29/2015 04:38:35 AM   NYPD
# 300697    30281825  03/29/2015 12:33:01 AM  03/29/2015 04:41:50 AM   NYPD
#
#                             Agency Name           Complaint Type  \
# 0       New York City Police Department  Noise - Street/Sidewalk
# 1       New York City Police Department         Blocked Driveway
# 2       New York City Police Department         Blocked Driveway
# 3       New York City Police Department          Illegal Parking
# 4       New York City Police Department          Illegal Parking
# ...                                 ...                      ...
# 300693  New York City Police Department       Noise - Commercial
# 300694  New York City Police Department         Blocked Driveway
# 300695  New York City Police Department       Noise - Commercial
# 300696  New York City Police Department       Noise - Commercial
# 300697  New York City Police Department       Noise - Commercial
#
#                           Descriptor        Location Type  Incident Zip  \
# 0                   Loud Music/Party      Street/Sidewalk       10034.0
# 1                          No Access      Street/Sidewalk       11105.0
# 2                          No Access      Street/Sidewalk       10458.0
# 3       Commercial Overnight Parking      Street/Sidewalk       10461.0
# 4                   Blocked Sidewalk      Street/Sidewalk       11373.0
# ...                              ...                  ...           ...
# 300693              Loud Music/Party  Club/Bar/Restaurant           NaN
# 300694                Partial Access      Street/Sidewalk       11418.0
# 300695              Loud Music/Party  Club/Bar/Restaurant       11206.0
# 300696              Loud Music/Party  Club/Bar/Restaurant       10461.0
# 300697              Loud Music/Party     Store/Commercial       10036.0
#
#                 Incident Address  ... Bridge Highway Name  \
# 0            71 VERMILYEA AVENUE  ...                 NaN
# 1                27-07 23 AVENUE  ...                 NaN
# 2          2897 VALENTINE AVENUE  ...                 NaN
# 3            2940 BAISLEY AVENUE  ...                 NaN
# 4                  87-14 57 ROAD  ...                 NaN
# ...                          ...  ...                 ...
# 300693           CRESCENT AVENUE  ...                 NaN
# 300694          100-17 87 AVENUE  ...                 NaN
# 300695         162 THROOP AVENUE  ...                 NaN
# 300696  3151 EAST TREMONT AVENUE  ...                 NaN
# 300697        251 WEST 48 STREET  ...                 NaN
#
#        Bridge Highway Direction Road Ramp Bridge Highway Segment  \
# 0                           NaN       NaN                    NaN
# 1                           NaN       NaN                    NaN
# 2                           NaN       NaN                    NaN
# 3                           NaN       NaN                    NaN
# 4                           NaN       NaN                    NaN
# ...                         ...       ...                    ...
# 300693                      NaN       NaN                    NaN
# 300694                      NaN       NaN                    NaN
# 300695                      NaN       NaN                    NaN
# 300696                      NaN       NaN                    NaN
# 300697                      NaN       NaN                    NaN
#
#        Garage Lot Name Ferry Direction Ferry Terminal Name   Latitude  \
# 0                  NaN             NaN                 NaN  40.865682
# 1                  NaN             NaN                 NaN  40.775945
# 2                  NaN             NaN                 NaN  40.870325
# 3                  NaN             NaN                 NaN  40.835994
# 4                  NaN             NaN                 NaN  40.733060
# ...                ...             ...                 ...        ...
# 300693             NaN             NaN                 NaN        NaN
# 300694             NaN             NaN                 NaN  40.694077
# 300695             NaN             NaN                 NaN  40.699590
# 300696             NaN             NaN                 NaN  40.837708
# 300697             NaN             NaN                 NaN  40.760583
#
#         Longitude                                  Location
# 0      -73.923501   (40.86568153633767, -73.92350095571744)
# 1      -73.915094  (40.775945312321085, -73.91509393898605)
# 2      -73.888525  (40.870324522111424, -73.88852464418646)
# 3      -73.828379   (40.83599404683083, -73.82837939584206)
# 4      -73.874170  (40.733059618956815, -73.87416975810375)
# ...           ...                                       ...
# 300693        NaN                                       NaN
# 300694 -73.846087    (40.69407728322387, -73.8460866160573)
# 300695 -73.944234   (40.69959035300927, -73.94423377144169)
# 300696 -73.834587    (40.8377075854206, -73.83458731019586)
# 300697 -73.985922   (40.76058322950115, -73.98592204392392)
#
# [300698 rows x 53 columns]

# %%
dataset.shape
# Out:
# (300698, 53)

# %%
dataset.isnull().sum()
# Out:
# Unique Key                             0
# Created Date                           0
# Closed Date                         2164
# Agency                                 0
# Agency Name                            0
# Complaint Type                         0
# Descriptor                          5914
# Location Type                        131
# Incident Zip                        2615
# Incident Address                   44410
# Street Name                        44410
# Cross Street 1                     49279
# Cross Street 2                     49779
# Intersection Street 1             256840
# Intersection Street 2             257336
# Address Type                        2815
# City                                2614
# Landmark                          300349
# Facility Type                       2171
# Status                                 0
# Due Date                               3
# Resolution Description                 0
# Resolution Action Updated Date      2187
# Community Board                        0
# Borough                                0
# X Coordinate (State Plane)          3540
# Y Coordinate (State Plane)          3540
# Park Facility Name                     0
# Park Borough                           0
# School Name                            0
# School Number                          0
# School Region                          1
# School Code                            1
# School Phone Number                    0
# School Address                         0
# School City                            0
# School State                           0
# School Zip                             1
# School Not Found                       0
# School or Citywide Complaint      300698
# Vehicle Type                      300698
# Taxi Company Borough              300698
# Taxi Pick Up Location             300698
# Bridge Highway Name               300455
# Bridge Highway Direction          300455
# Road Ramp                         300485
# Bridge Highway Segment            300485
# Garage Lot Name                   300698
# Ferry Direction                   300697
# Ferry Terminal Name               300696
# Latitude                            3540
# Longitude                           3540
# Location                            3540
# dtype: int64

# %%
dataset.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'Borough', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'Park Facility Name', 'Park Borough',
#        'School Name', 'School Number', 'School Region', 'School Code',
#        'School Phone Number', 'School Address', 'School City', 'School State',
#        'School Zip', 'School Not Found', 'School or Citywide Complaint',
#        'Vehicle Type', 'Taxi Company Borough', 'Taxi Pick Up Location',
#        'Bridge Highway Name', 'Bridge Highway Direction', 'Road Ramp',
#        'Bridge Highway Segment', 'Garage Lot Name', 'Ferry Direction',
#        'Ferry Terminal Name', 'Latitude', 'Longitude', 'Location'],
#       dtype='object')

# %% [markdown]
# # Perform basic data exploratory analysis

# %%
service_dataset = dataset.drop(['School or Citywide Complaint','Vehicle Type','Taxi Company Borough','Taxi Pick Up Location','Bridge Highway Name','Bridge Highway Direction','Road Ramp','Bridge Highway Segment','Garage Lot Name','Ferry Direction','Ferry Terminal Name','Intersection Street 1','Intersection Street 2','Landmark','Park Facility Name','School Name', 'School Number', 'School Region', 'School Code','School Phone Number', 'School Address', 'School City', 'School State','School Zip','School Not Found'],axis=1)

# %%
service_dataset.shape
# Out:
# (300698, 28)

# %%
service_dataset.isnull().sum()
# Out:
# Unique Key                            0
# Created Date                          0
# Closed Date                        2164
# Agency                                0
# Agency Name                           0
# Complaint Type                        0
# Descriptor                         5914
# Location Type                       131
# Incident Zip                       2615
# Incident Address                  44410
# Street Name                       44410
# Cross Street 1                    49279
# Cross Street 2                    49779
# Address Type                       2815
# City                               2614
# Facility Type                      2171
# Status                                0
# Due Date                              3
# Resolution Description                0
# Resolution Action Updated Date     2187
# Community Board                       0
# Borough                               0
# X Coordinate (State Plane)         3540
# Y Coordinate (State Plane)         3540
# Park Borough                          0
# Latitude                           3540
# Longitude                          3540
# Location                           3540
# dtype: int64

# %%
service_dataset
# Out:
#         Unique Key            Created Date             Closed Date Agency  \
# 0         32310363  12/31/2015 11:59:45 PM           01-01-16 0:55   NYPD
# 1         32309934  12/31/2015 11:59:44 PM           01-01-16 1:26   NYPD
# 2         32309159  12/31/2015 11:59:29 PM           01-01-16 4:51   NYPD
# 3         32305098  12/31/2015 11:57:46 PM           01-01-16 7:43   NYPD
# 4         32306529  12/31/2015 11:56:58 PM           01-01-16 3:24   NYPD
# ...            ...                     ...                     ...    ...
# 300693    30281872  03/29/2015 12:33:41 AM                     NaN   NYPD
# 300694    30281230  03/29/2015 12:33:28 AM  03/29/2015 02:33:59 AM   NYPD
# 300695    30283424  03/29/2015 12:33:03 AM  03/29/2015 03:40:20 AM   NYPD
# 300696    30280004  03/29/2015 12:33:02 AM  03/29/2015 04:38:35 AM   NYPD
# 300697    30281825  03/29/2015 12:33:01 AM  03/29/2015 04:41:50 AM   NYPD
#
#                             Agency Name           Complaint Type  \
# 0       New York City Police Department  Noise - Street/Sidewalk
# 1       New York City Police Department         Blocked Driveway
# 2       New York City Police Department         Blocked Driveway
# 3       New York City Police Department          Illegal Parking
# 4       New York City Police Department          Illegal Parking
# ...                                 ...                      ...
# 300693  New York City Police Department       Noise - Commercial
# 300694  New York City Police Department         Blocked Driveway
# 300695  New York City Police Department       Noise - Commercial
# 300696  New York City Police Department       Noise - Commercial
# 300697  New York City Police Department       Noise - Commercial
#
#                           Descriptor        Location Type  Incident Zip  \
# 0                   Loud Music/Party      Street/Sidewalk       10034.0
# 1                          No Access      Street/Sidewalk       11105.0
# 2                          No Access      Street/Sidewalk       10458.0
# 3       Commercial Overnight Parking      Street/Sidewalk       10461.0
# 4                   Blocked Sidewalk      Street/Sidewalk       11373.0
# ...                              ...                  ...           ...
# 300693              Loud Music/Party  Club/Bar/Restaurant           NaN
# 300694                Partial Access      Street/Sidewalk       11418.0
# 300695              Loud Music/Party  Club/Bar/Restaurant       11206.0
# 300696              Loud Music/Party  Club/Bar/Restaurant       10461.0
# 300697              Loud Music/Party     Store/Commercial       10036.0
#
#                 Incident Address  ...  \
# 0            71 VERMILYEA AVENUE  ...
# 1                27-07 23 AVENUE  ...
# 2          2897 VALENTINE AVENUE  ...
# 3            2940 BAISLEY AVENUE  ...
# 4                  87-14 57 ROAD  ...
# ...                          ...  ...
# 300693           CRESCENT AVENUE  ...
# 300694          100-17 87 AVENUE  ...
# 300695         162 THROOP AVENUE  ...
# 300696  3151 EAST TREMONT AVENUE  ...
# 300697        251 WEST 48 STREET  ...
#
#                                    Resolution Description  \
# 0       The Police Department responded and upon arriv...
# 1       The Police Department responded to the complai...
# 2       The Police Department responded and upon arriv...
# 3       The Police Department responded to the complai...
# 4       The Police Department responded and upon arriv...
# ...                                                   ...
# 300693  Your complaint has been forwarded to the New Y...
# 300694  The Police Department responded and upon arriv...
# 300695  The Police Department responded to the complai...
# 300696  The Police Department responded to the complai...
# 300697  The Police Department responded to the complai...
#
#        Resolution Action Updated Date Community Board      Borough  \
# 0                       01-01-16 0:55    12 MANHATTAN    MANHATTAN
# 1                       01-01-16 1:26       01 QUEENS       QUEENS
# 2                       01-01-16 4:51        07 BRONX        BRONX
# 3                       01-01-16 7:43        10 BRONX        BRONX
# 4                       01-01-16 3:24       04 QUEENS       QUEENS
# ...                               ...             ...          ...
# 300693                            NaN   0 Unspecified  Unspecified
# 300694         03/29/2015 02:33:59 AM       09 QUEENS       QUEENS
# 300695         03/29/2015 03:40:20 AM     03 BROOKLYN     BROOKLYN
# 300696         03/29/2015 04:38:35 AM        10 BRONX        BRONX
# 300697         03/29/2015 04:41:50 AM    05 MANHATTAN    MANHATTAN
#
#        X Coordinate (State Plane) Y Coordinate (State Plane) Park Borough  \
# 0                       1005409.0                   254678.0    MANHATTAN
# 1                       1007766.0                   221986.0       QUEENS
# 2                       1015081.0                   256380.0        BRONX
# 3                       1031740.0                   243899.0        BRONX
# 4                       1019123.0                   206375.0       QUEENS
# ...                           ...                        ...          ...
# 300693                        NaN                        NaN  Unspecified
# 300694                  1026931.0                   192185.0       QUEENS
# 300695                   999713.0                   194161.0     BROOKLYN
# 300696                  1030021.0                   244520.0        BRONX
# 300697                   988150.0                   216378.0    MANHATTAN
#
#          Latitude  Longitude                                  Location
# 0       40.865682 -73.923501   (40.86568153633767, -73.92350095571744)
# 1       40.775945 -73.915094  (40.775945312321085, -73.91509393898605)
# 2       40.870325 -73.888525  (40.870324522111424, -73.88852464418646)
# 3       40.835994 -73.828379   (40.83599404683083, -73.82837939584206)
# 4       40.733060 -73.874170  (40.733059618956815, -73.87416975810375)
# ...           ...        ...                                       ...
# 300693        NaN        NaN                                       NaN
# 300694  40.694077 -73.846087    (40.69407728322387, -73.8460866160573)
# 300695  40.699590 -73.944234   (40.69959035300927, -73.94423377144169)
# 300696  40.837708 -73.834587    (40.8377075854206, -73.83458731019586)
# 300697  40.760583 -73.985922   (40.76058322950115, -73.98592204392392)
#
# [300698 rows x 28 columns]

# %%
service_dataset.dropna(inplace=True)

# %%
service_dataset.isnull().sum()
# Out:
# Unique Key                        0
# Created Date                      0
# Closed Date                       0
# Agency                            0
# Agency Name                       0
# Complaint Type                    0
# Descriptor                        0
# Location Type                     0
# Incident Zip                      0
# Incident Address                  0
# Street Name                       0
# Cross Street 1                    0
# Cross Street 2                    0
# Address Type                      0
# City                              0
# Facility Type                     0
# Status                            0
# Due Date                          0
# Resolution Description            0
# Resolution Action Updated Date    0
# Community Board                   0
# Borough                           0
# X Coordinate (State Plane)        0
# Y Coordinate (State Plane)        0
# Park Borough                      0
# Latitude                          0
# Longitude                         0
# Location                          0
# dtype: int64

# %%
service_dataset.shape
# Out:
# (245664, 28)

# %% [markdown]
# # Analyze the date column and remove the entries if it has an incorrect timeline

# %%
service_dataset['Created Date']
# Out:
# 0         12/31/2015 11:59:45 PM
# 1         12/31/2015 11:59:44 PM
# 2         12/31/2015 11:59:29 PM
# 3         12/31/2015 11:57:46 PM
# 4         12/31/2015 11:56:58 PM
#                    ...
# 300692    03/29/2015 12:34:32 AM
# 300694    03/29/2015 12:33:28 AM
# 300695    03/29/2015 12:33:03 AM
# 300696    03/29/2015 12:33:02 AM
# 300697    03/29/2015 12:33:01 AM
# Name: Created Date, Length: 245664, dtype: object

# %%
service_dataset['Created Date'] = pd.to_datetime(service_dataset['Created Date'])
service_dataset['Closed Date'] = pd.to_datetime(service_dataset['Closed Date'])
# Out:
# <ipython-input-15-06877b52094c>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   service_dataset['Created Date'] = pd.to_datetime(service_dataset['Created Date'])
# <ipython-input-15-06877b52094c>:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   service_dataset['Closed Date'] = pd.to_datetime(service_dataset['Closed Date'])

# %%
service_dataset.loc[service_dataset['Created Date']>=service_dataset['Closed Date']].shape
# Out:
# (0, 28)

# %%
service_dataset = service_dataset[service_dataset['Closed Date'].notnull()]

# %% [markdown]
# # Draw a frequency plot for city-wise complaints

# %%
plt.figure(figsize=(10,10))
service_dataset['City'].value_counts().plot(kind='barh',color='b')
plt.xlabel('Count')
plt.ylabel('City')
plt.title('City-wise Complaints')
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.countplot(y=service_dataset['City'])
plt.title('City-wise Complaints')
plt.show()

# %% [markdown]
# # Draw scatter and hexbin plots for complaint concentration across Brooklyn

# %%
def to_title(city):
    try:
        city = city.title()
        return city
    except:
        return np.nan

service_dataset['City'] = service_dataset['City'].apply(to_title)
service_dataset['City'].value_counts()
# Out:
# City
# Brooklyn               84197
# New York               48429
# Bronx                  34518
# Staten Island          10283
# Astoria                 6232
# Jamaica                 5706
# Flushing                5170
# Ridgewood               4373
# Corona                  3918
# Woodside                3093
# South Richmond Hill     2544
# East Elmhurst           2465
# Ozone Park              2389
# Elmhurst                2388
# Woodhaven               2221
# Long Island City        2063
# Maspeth                 1999
# South Ozone Park        1886
# Richmond Hill           1715
# Fresh Meadows           1616
# Queens Village          1463
# Middle Village          1455
# Jackson Heights         1441
# Forest Hills            1320
# Rego Park               1255
# College Point           1090
# Bayside                  975
# Far Rockaway             915
# Hollis                   896
# Whitestone               852
# Springfield Gardens      736
# Howard Beach             730
# Kew Gardens              696
# Rosedale                 643
# Saint Albans             633
# Rockaway Park            595
# Sunnyside                590
# Little Neck              477
# Cambria Heights          386
# Oakland Gardens          379
# Bellerose                296
# Glen Oaks                226
# Arverne                  173
# Floral Park              130
# New Hyde Park             79
# Breezy Point              28
# Name: count, dtype: int64

# %%
service_dataset.groupby(['City','Complaint Type']).size()
# Out:
# City      Complaint Type
# Arverne   Animal Abuse                37
#           Blocked Driveway            35
#           Derelict Vehicle            21
#           Disorderly Youth             1
#           Graffiti                     1
#                                     ...
# Woodside  Noise - Park                11
#           Noise - Street/Sidewalk    226
#           Noise - Vehicle             90
#           Traffic                     11
#           Vending                      7
# Length: 554, dtype: int64

# %%
brooklyn = service_dataset.loc[service_dataset['City']=='Brooklyn']

# %%
brooklyn[['Longitude', 'Latitude']].plot(kind = 'hexbin', x='Longitude', y='Latitude', gridsize=40,
    colormap = 'jet', mincnt=1, title = 'Complaints Concentration in Brooklyn', figsize = (10, 8));

# %% [markdown]
# # Find major types of complaints

# %%
plt.figure(figsize=(10,10))
sns.countplot(y=service_dataset['Complaint Type'])
plt.title('Count vs. Complaint types')
plt.show()

# %%
plt.figure(figsize=(10,10))
service_dataset['Complaint Type'].value_counts().plot(kind='barh',color='b')
plt.xlabel('Count')
plt.ylabel('Complaint Type')
plt.title('Count vs Complaint Type')
plt.show()

# %% [markdown]
# # Find the top 10 types of complaints

# %%
dfTop10=service_dataset.groupby('Complaint Type').size().sort_values(ascending=False)[:10]
dfTop10
# Out:
# Complaint Type
# Blocked Driveway           75291
# Illegal Parking            60145
# Noise - Street/Sidewalk    38033
# Noise - Commercial         32020
# Derelict Vehicle           14477
# Noise - Vehicle            12122
# Animal Abuse                6573
# Vending                     2211
# Noise - Park                1270
# Drinking                    1007
# dtype: int64

# %% [markdown]
# # Display the types of complaints in each city in a separate dataset

# %%
service_dataset.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Address Type', 'City', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'Borough', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'Park Borough', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %%
dfcomplaint = service_dataset.drop(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
       'Descriptor', 'Location Type', 'Incident Zip',
       'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
       'Address Type', 'Facility Type', 'Status', 'Due Date',
       'Resolution Description', 'Resolution Action Updated Date',
       'Community Board', 'Borough', 'X Coordinate (State Plane)',
       'Y Coordinate (State Plane)', 'Park Borough', 'Latitude', 'Longitude',
       'Location'],axis=1)

# %%
dfcomplaint
# Out:
#                  Complaint Type           City
# 0       Noise - Street/Sidewalk       New York
# 1              Blocked Driveway        Astoria
# 2              Blocked Driveway          Bronx
# 3               Illegal Parking          Bronx
# 4               Illegal Parking       Elmhurst
# ...                         ...            ...
# 300692       Noise - Commercial       New York
# 300694         Blocked Driveway  Richmond Hill
# 300695       Noise - Commercial       Brooklyn
# 300696       Noise - Commercial          Bronx
# 300697       Noise - Commercial       New York
#
# [245664 rows x 2 columns]

# %%
dfcomplaint.to_csv('Types of Complaints')

# %% [markdown]
# # Visualize the major types of complaints in each city

# %%
service_dataset.groupby(['City','Complaint Type']).size()
# Out:
# City      Complaint Type
# Arverne   Animal Abuse                37
#           Blocked Driveway            35
#           Derelict Vehicle            21
#           Disorderly Youth             1
#           Graffiti                     1
#                                     ...
# Woodside  Noise - Park                11
#           Noise - Street/Sidewalk    226
#           Noise - Vehicle             90
#           Traffic                     11
#           Vending                      7
# Length: 554, dtype: int64

# %%
# pivot table
crosstab=pd.crosstab(index=service_dataset['City'],columns=service_dataset['Complaint Type'])
crosstab
# Out:
# Complaint Type       Animal Abuse  Blocked Driveway  Derelict Vehicle  \
# City
# Arverne                        37                35                21
# Astoria                       110              2687               291
# Bayside                        34               371               153
# Bellerose                       5                94                61
# Breezy Point                    2                 3                 3
# Bronx                        1254             12538              1607
# Brooklyn                     2134             27711              4425
# Cambria Heights                 9               147                86
# College Point                  24               426               165
# Corona                         59              2727                48
# East Elmhurst                  54              1383                91
# Elmhurst                       22              1430                60
# Far Rockaway                   81               280               130
# Floral Park                     2                20                43
# Flushing                      128              2741               367
# Forest Hills                   34               649                41
# Fresh Meadows                  42               488               242
# Glen Oaks                       3                28                44
# Hollis                         29               335               131
# Howard Beach                   29               163               102
# Jackson Heights                39               553                26
# Jamaica                       194              2757               781
# Kew Gardens                    18               309                12
# Little Neck                    12               119                43
# Long Island City               24               773               167
# Maspeth                        33               720               340
# Middle Village                 21               452               247
# New Hyde Park                   1                51                13
# New York                     1023              1923               426
# Oakland Gardens                16               127                58
# Ozone Park                     43              1235               368
# Queens Village                 57               582               291
# Rego Park                      25               595                63
# Richmond Hill                  27               860               146
# Ridgewood                     103              1627               263
# Rockaway Park                  27                65                 5
# Rosedale                       32               207               174
# Saint Albans                   23               236               165
# South Ozone Park               51               924               305
# South Richmond Hill            21              1530               241
# Springfield Gardens            20               257               177
# Staten Island                 524              2103              1429
# Sunnyside                      31               202                 8
# Whitestone                     26               207               169
# Woodhaven                      40              1039               275
# Woodside                       50              1582               174
#
# Complaint Type       Disorderly Youth  Drinking  Graffiti  Illegal Parking  \
# City
# Arverne                             1         0         1               43
# Astoria                             2        27         4             1098
# Bayside                             0         1         3              363
# Bellerose                           2         1         0               78
# Breezy Point                        0         1         0               13
# Bronx                              47       152         8             6256
# Brooklyn                           54       203        37            23235
# Cambria Heights                     0         0         0               45
# College Point                       0         0         1              304
# Corona                              3        19         2              537
# East Elmhurst                       1         7         2              738
# Elmhurst                            1        11         0              553
# Far Rockaway                        1         3         0              219
# Floral Park                         1         1         0               57
# Flushing                            1        22         4             1486
# Forest Hills                        1         1         3              352
# Fresh Meadows                       0         2         0              783
# Glen Oaks                           0         0         0               46
# Hollis                              0         3         0              120
# Howard Beach                        0         4         0              206
# Jackson Heights                     0         7         0              144
# Jamaica                             5        25         3             1031
# Kew Gardens                         0         1         0              176
# Little Neck                         2         1         0              214
# Long Island City                    0         5         2              629
# Maspeth                             0         5         0              718
# Middle Village                      0         2         0              664
# New Hyde Park                       0         0         0               12
# New York                           35       243        14             9477
# Oakland Gardens                     0         1         0              157
# Ozone Park                          3         9         0              500
# Queens Village                      0         3         0              405
# Rego Park                           0         2         1              418
# Richmond Hill                       0         7         1              319
# Ridgewood                           2         7         2             1471
# Rockaway Park                       1        20         0              250
# Rosedale                            0         2         1              156
# Saint Albans                        0         3         0               99
# South Ozone Park                    0        12         0              395
# South Richmond Hill                 2        20         0              397
# Springfield Gardens                 0         4         0              190
# Staten Island                      18       153         2             3974
# Sunnyside                           1         4         1               92
# Whitestone                          0         2         1              400
# Woodhaven                           0         3         0              571
# Woodside                            1         8         2              754
#
# Complaint Type       Noise - Commercial  Noise - House of Worship  \
# City
# Arverne                               2                        10
# Astoria                            1406                        16
# Bayside                              29                         2
# Bellerose                            36                         1
# Breezy Point                          4                         0
# Bronx                              2145                        55
# Brooklyn                          10528                       225
# Cambria Heights                       7                         2
# College Point                        21                         0
# Corona                              226                         1
# East Elmhurst                        31                        17
# Elmhurst                             68                         4
# Far Rockaway                         42                         1
# Floral Park                           2                         0
# Flushing                            158                         2
# Forest Hills                        117                         1
# Fresh Meadows                        13                         0
# Glen Oaks                            73                         0
# Hollis                               23                       183
# Howard Beach                        209                         0
# Jackson Heights                     445                         2
# Jamaica                             373                        10
# Kew Gardens                         159                         1
# Little Neck                          68                         0
# Long Island City                    217                         0
# Maspeth                              46                         1
# Middle Village                        8                         0
# New Hyde Park                         0                         0
# New York                          13336                       139
# Oakland Gardens                       0                         0
# Ozone Park                           99                         3
# Queens Village                       38                         0
# Rego Park                            68                         0
# Richmond Hill                       213                         0
# Ridgewood                           368                         2
# Rockaway Park                        33                         0
# Rosedale                             19                         1
# Saint Albans                         22                         0
# South Ozone Park                     54                         2
# South Richmond Hill                 184                         3
# Springfield Gardens                  31                         0
# Staten Island                       585                        10
# Sunnyside                           155                         0
# Whitestone                           10                         0
# Woodhaven                           173                         1
# Woodside                            176                         1
#
# Complaint Type       Noise - Park  Noise - Street/Sidewalk  Noise - Vehicle  \
# City
# Arverne                         0                       18                4
# Astoria                        25                      395              126
# Bayside                         1                        5               11
# Bellerose                       0                        9                6
# Breezy Point                    0                        1                1
# Bronx                         214                     7371             2553
# Brooklyn                      449                    10721             3913
# Cambria Heights                 0                       17               71
# College Point                   0                       21              126
# Corona                          8                      160               79
# East Elmhurst                   4                       77               52
# Elmhurst                        3                      181               36
# Far Rockaway                    7                       93               50
# Floral Park                     0                        3                1
# Flushing                       15                      129               78
# Forest Hills                    6                       67               34
# Fresh Meadows                   3                       30               12
# Glen Oaks                      20                        4                1
# Hollis                          2                       26               40
# Howard Beach                    0                       10                4
# Jackson Heights                 4                      125               41
# Jamaica                         6                      240              192
# Kew Gardens                     0                        7               10
# Little Neck                     1                        6                4
# Long Island City               12                      121               81
# Maspeth                         1                      107               17
# Middle Village                  1                       25               30
# New Hyde Park                   0                        0                2
# New York                      418                    16097             3589
# Oakland Gardens                 3                       13                3
# Ozone Park                      2                       77               45
# Queens Village                  1                       44               31
# Rego Park                      18                       36               24
# Richmond Hill                   0                       80               46
# Ridgewood                       4                      346              159
# Rockaway Park                   2                      163               23
# Rosedale                        4                       16               18
# Saint Albans                    0                       50               28
# South Ozone Park                1                       66               65
# South Richmond Hill             0                       61               66
# Springfield Gardens             0                       25               28
# Staten Island                  20                      643              239
# Sunnyside                       2                       47               29
# Whitestone                      1                       18               12
# Woodhaven                       1                       56               52
# Woodside                       11                      226               90
#
# Complaint Type       Posting Advertisement  Traffic  Vending
# City
# Arverne                                  0        0        1
# Astoria                                  0       14       31
# Bayside                                  0        2        0
# Bellerose                                0        3        0
# Breezy Point                             0        0        0
# Bronx                                   12       64      242
# Brooklyn                                39      264      259
# Cambria Heights                          0        2        0
# College Point                            0        1        1
# Corona                                   0        4       45
# East Elmhurst                            1        3        4
# Elmhurst                                 1        3       15
# Far Rockaway                             0        4        4
# Floral Park                              0        0        0
# Flushing                                 1       13       25
# Forest Hills                             3        9        2
# Fresh Meadows                            0        1        0
# Glen Oaks                                0        1        6
# Hollis                                   0        4        0
# Howard Beach                             0        2        1
# Jackson Heights                          1        2       52
# Jamaica                                  7       74        8
# Kew Gardens                              0        2        1
# Little Neck                              1        6        0
# Long Island City                         1        8       23
# Maspeth                                  0        7        4
# Middle Village                           0        5        0
# New Hyde Park                            0        0        0
# New York                                35      269     1405
# Oakland Gardens                          0        1        0
# Ozone Park                               1        3        1
# Queens Village                           1       10        0
# Rego Park                                0        3        2
# Richmond Hill                            0        3       13
# Ridgewood                                1       13        5
# Rockaway Park                            0        4        2
# Rosedale                                 0        5        8
# Saint Albans                             0        6        1
# South Ozone Park                         0       10        1
# South Richmond Hill                      0        6       13
# Springfield Gardens                      0        3        1
# Staten Island                          514       51       18
# Sunnyside                                2       10        6
# Whitestone                               0        6        0
# Woodhaven                                0        6        4
# Woodside                                 0       11        7

# %%
crosstab.plot(kind='bar',figsize=(12,8),stacked=True,colormap='Paired')
# Out:
# <Axes: xlabel='City'>

# %% [markdown]
# # Check if the average response time across various types of complaints

# %%
service_dataset["Request_Closing_Time"]=(service_dataset["Closed Date"]-service_dataset["Created Date"])

Request_Closing_Time=[]
for x in (service_dataset["Closed Date"]-service_dataset["Created Date"]):
    close=x.total_seconds()/60
    Request_Closing_Time.append(close)

service_dataset["Request_Closing_Time"]=Request_Closing_Time

# %%
pd.DataFrame(service_dataset.groupby("Location Type")["Request_Closing_Time"].mean()).sort_values("Request_Closing_Time")
# Out:
#                             Request_Closing_Time
# Location Type
# Highway                                76.941667
# Club/Bar/Restaurant                   185.804348
# Store/Commercial                      193.505656
# House of Worship                      198.220354
# Subway Station                        203.712500
# Park/Playground                       209.318891
# Commercial                            240.489080
# Street/Sidewalk                       271.662240
# Residential Building                  294.279984
# House and Store                       312.464609
# Residential Building/House            315.827304
# Parking Lot                           347.801408
# Vacant Lot                            452.562281
# Roadway Tunnel                        984.929167

# %% [markdown]
# # Identify significant variables by performing a statistical analysis using p-values and chi-square values

# %%
from scipy import stats
from scipy.stats import chi2_contingency

import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
service_dataset.shape
# Out:
# (245664, 29)

# %%
new_df=service_dataset.loc[:,(service_dataset.isnull().sum()/service_dataset.shape[0]*100)<=50]

# %%
rem=[]
for x in new_df.columns.tolist():
    if new_df[x].nunique()<=3:
        print(x+ " "*10+" : ",new_df[x].unique())
        rem.append(x)
# Out:
# Agency           :  ['NYPD']
# Agency Name           :  ['New York City Police Department']
# Address Type           :  ['ADDRESS' 'BLOCKFACE' 'INTERSECTION']
# Facility Type           :  ['Precinct']
# Status           :  ['Closed']

# %%
new_df.shape
# Out:
# (245664, 29)

# %%
rem1=["Unique Key","Incident Address","Descriptor","Street Name","Cross Street 1","Cross Street 2","Due Date","Resolution Description","Resolution Action Updated Date","Community Board","X Coordinate (State Plane)","Y Coordinate (State Plane)","Park Borough","Latitude","Longitude","Location"]

new_df.drop(rem1,axis=1,inplace=True)

# %%
new_df.head()
# Out:
#          Created Date         Closed Date Agency  \
# 0 2015-12-31 23:59:45 2016-01-01 00:55:00   NYPD
# 1 2015-12-31 23:59:44 2016-01-01 01:26:00   NYPD
# 2 2015-12-31 23:59:29 2016-01-01 04:51:00   NYPD
# 3 2015-12-31 23:57:46 2016-01-01 07:43:00   NYPD
# 4 2015-12-31 23:56:58 2016-01-01 03:24:00   NYPD
#
#                        Agency Name           Complaint Type    Location Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk  Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway  Street/Sidewalk
# 2  New York City Police Department         Blocked Driveway  Street/Sidewalk
# 3  New York City Police Department          Illegal Parking  Street/Sidewalk
# 4  New York City Police Department          Illegal Parking  Street/Sidewalk
#
#    Incident Zip Address Type      City Facility Type  Status    Borough  \
# 0       10034.0      ADDRESS  New York      Precinct  Closed  MANHATTAN
# 1       11105.0      ADDRESS   Astoria      Precinct  Closed     QUEENS
# 2       10458.0      ADDRESS     Bronx      Precinct  Closed      BRONX
# 3       10461.0      ADDRESS     Bronx      Precinct  Closed      BRONX
# 4       11373.0      ADDRESS  Elmhurst      Precinct  Closed     QUEENS
#
#    Request_Closing_Time
# 0             55.250000
# 1             86.266667
# 2            291.516667
# 3            465.233333
# 4            207.033333

# %%
g=sns.catplot(x="Complaint Type",y="Request_Closing_Time",kind="box",data=new_df)
g.fig.set_figheight(8)
g.fig.set_figwidth(15)
plt.xticks(rotation=90)
plt.ylim((0,2000))
# Out:
# (0.0, 2000.0)

# %%
anova_df=pd.DataFrame()
anova_df["Request_Closing_Time"]=new_df["Request_Closing_Time"]
anova_df["Complaint"]=new_df["Complaint Type"]

anova_df.dropna(inplace=True)
anova_df.head()
# Out:
#    Request_Closing_Time                Complaint
# 0             55.250000  Noise - Street/Sidewalk
# 1             86.266667         Blocked Driveway
# 2            291.516667         Blocked Driveway
# 3            465.233333          Illegal Parking
# 4            207.033333          Illegal Parking

# %%
lm=ols("Request_Closing_Time~Complaint",data=anova_df).fit()
table=sm.stats.anova_lm(lm)
table
# Out:
#                  df        sum_sq       mean_sq           F  PR(>F)
# Complaint      14.0  8.182382e+08  5.844559e+07  470.919464     0.0
# Residual   245649.0  3.048738e+10  1.241095e+05         NaN     NaN

# %%
chi_sq=pd.DataFrame()
chi_sq["Location Type"]=new_df["Location Type"]
chi_sq["Complaint Type"]=new_df["Complaint Type"]

chi_sq.dropna(inplace=True)

# %%
data_crosstab = pd.crosstab( chi_sq["Location Type"],chi_sq["Complaint Type"])

# %%
stat, p, dof, expected = chi2_contingency(data_crosstab)

alpha = 0.05
if p <= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (H0 holds true)')
# Out:
# Dependent (reject H0)
